# %% [markdown]
# # Create a SQLite3 schema to store Spotify data in at least 3rd normal form (3NF), and populate the tables.

# %% [markdown]
# Data source: [https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-01-21/readme.md](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-01-21/readme.md)

# %%
import numpy as np
import pandas as pd
import sqlite3
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
# %load_ext sql

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')

# %% [markdown]
# ## Normalization
#
# - Every table should not have any
#     - duplication
#     - dependencies that are not key or domain constraints

# %%
## check duplicates
df.duplicated().any()
# Out:
# False

# %% [markdown]
# There seem to be no duplicate rows in the data frame.

# %% [markdown]
# ### 1NF
#
# - Split composite entries

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %% [markdown]
# The data frame does not seem to have any compound entries, so the data frame already satisfies the first normal form.

# %% [markdown]
# ### 2NF
#
# - Break partial dependencies
#     - Identify candidate Primary Key for each row
#     - If there is a composite Primary Key, see if other columns have partial dependencies

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %% [markdown]
# In the codebook, `track_id` is the unique ID for each song, so it is possibly the Primary Key.

# %% [markdown]
# #### (1) Playlist:

# %%
playlist = df[df.duplicated(subset=['playlist_id'])]
playlist.sort_values(by = ['playlist_id'], axis=0)[['playlist_id','playlist_name','playlist_genre','playlist_subgenre']].head()
# Out:
#                  playlist_id   playlist_name playlist_genre playlist_subgenre
# 7949  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7935  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7936  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7937  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7938  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop

# %% [markdown]
# From the above table, we can see that `playlist_name`, `playlist_genre` and `playlist_subgenre` all depend on `playlist_id`.

# %%
df_playlist = df[['playlist_id', 'playlist_name', 'playlist_genre', 'playlist_subgenre']].drop_duplicates()

# %% [markdown]
# #### (2) Album:

# %%
album = df[df.duplicated(subset=['track_album_id'])]
album.sort_values(by = ['track_album_id'], axis=0)[['track_album_id', 'track_album_name', 'track_album_release_date']].head()
# Out:
#                track_album_id              track_album_name  \
# 25103  006AgHXrEw13oyg0D8evRa  Bad Boy Greatest Hits Vol. 1
# 11218  007DWn799UWvfY1wwZeENR                  i am > i was
# 11244  007DWn799UWvfY1wwZeENR                  i am > i was
# 11242  007DWn799UWvfY1wwZeENR                  i am > i was
# 8985   007DWn799UWvfY1wwZeENR                  i am > i was
#
#       track_album_release_date
# 25103                     1998
# 11218               2018-12-21
# 11244               2018-12-21
# 11242               2018-12-21
# 8985                2018-12-21

# %% [markdown]
# From the above table, we can see that `track_album_name` and `track_album_release_date` all depend on `track_album_id`.

# %%
df_album = df[['track_album_id','track_album_name', 'track_album_release_date']].drop_duplicates()

# %% [markdown]
# #### (3) Song:

# %%
song = df[df.duplicated(subset=['track_id'])]
song.sort_values(by = ['track_id'], axis=0)[['track_id','track_name', 'track_artist','track_popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                                             'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','duration_ms']].head()
# Out:
#                      track_id                       track_name track_artist  \
# 32084  00Gu3RMpDW2vO9PjlMVFDL    Hide Away (feat. Envy Monroe)  Blasterjaxx
# 23850  00QyLmjxaSEE8qIZQjBXBj       We Own It (Fast & Furious)     2 Chainz
# 28968  00QyLmjxaSEE8qIZQjBXBj       We Own It (Fast & Furious)     2 Chainz
# 9345   00ReeHCY0FQUyuAUyPJdnk  Ain't No Future In Yo' Frontin'     MC Breed
# 14626  00WIXhVVhswHuS6dlkScuw                              Hot     Confetti
#
#        track_popularity  danceability  energy  key  loudness  mode  \
# 32084                42         0.573   0.746   10    -4.894     1
# 23850                59         0.554   0.899    8    -4.573     1
# 28968                59         0.554   0.899    8    -4.573     1
# 9345                 48         0.672   0.761    0    -9.644     1
# 14626                51         0.607   0.908    7    -3.883     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 32084       0.0421       0.02490          0.000000    0.3610    0.134
# 23850       0.4080       0.05210          0.000000    0.0568    0.552
# 28968       0.4080       0.05210          0.000000    0.0568    0.552
# 9345        0.2480       0.05140          0.000000    0.4740    0.731
# 14626       0.1070       0.00297          0.000002    0.1200    0.664
#
#          tempo  duration_ms
# 32084  130.001       188000
# 23850  171.966       227893
# 28968  171.966       227893
# 9345   102.192       244733
# 14626  168.015       150714

# %% [markdown]
# From the above table, we can see that `track_name`, `track_popularity` and `track_artist` and other song characteristics all depend on `track_id`.

# %%
df_song = df[['track_id','track_name','track_artist','track_popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']].drop_duplicates()

# %%
df_song_playlist = df[['track_id', 'playlist_id']].drop_duplicates()
df_song_album = df[['track_id', 'track_album_id']].drop_duplicates()

# %% [markdown]
# ### 3NF
#
# - Remove transitive dependencies

# %%
df_playlist_ = df_playlist[['playlist_id', 'playlist_name', 'playlist_subgenre']]
df_playlist_genre = df_playlist[['playlist_subgenre', 'playlist_genre']].drop_duplicates()

# %%
df_playlist_genre
# Out:
#                playlist_subgenre playlist_genre
# 0                      dance pop            pop
# 1298               post-teen pop            pop
# 2427                  electropop            pop
# 3835             indie poptimism            pop
# 5507                     hip hop            rap
# 6829            southern hip hop            rap
# 8504                gangster rap            rap
# 9962                        trap            rap
# 11253                 album rock           rock
# 12318               classic rock           rock
# 13614             permanent wave           rock
# 14719                  hard rock           rock
# 16204                   tropical          latin
# 17492                  latin pop          latin
# 18754                  reggaeton          latin
# 19703              latin hip hop          latin
# 21359         urban contemporary            r&b
# 22764                    hip pop            r&b
# 24020             new jack swing            r&b
# 25153                   neo soul            r&b
# 26790              electro house            edm
# 28301                   big room            edm
# 29507                    pop edm            edm
# 31024  progressive electro house            edm

# %% [markdown]
# ## Final tables

# %%
df_song.sample(5)
# Out:
#                      track_id                                   track_name  \
# 9166   7nh0HBrSbnmCfAraHcg7vK                                Don't Push Me
# 15925  1Iga5GHOuh3RxXbWytxGfx                   This Is the Time (Ballast)
# 15652  2VXLXoliu0NTVAYE8Jx1QX  Pour Some Sugar On Me - Historia Video Edit
# 15061  004s3t0ONYlzxII9PLgU6z                                 I Feel Alive
# 23606  3ZJIaADn3QkIVjhK4z2CQ5                                   yuh (fool)
#
#         track_artist  track_popularity  danceability  energy  key  loudness  \
# 9166         50 Cent                52         0.504   0.782    1    -3.006
# 15925   Nothing More                 0         0.521   0.982   11    -4.639
# 15652    Def Leppard                 0         0.544   0.916    1    -5.031
# 15061  Steady Rollin                28         0.303   0.880    9    -4.739
# 23606        greisun                37         0.657   0.636    6    -5.444
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 9166      1       0.3420      0.050600          0.000000    0.0787    0.660
# 15925     0       0.0669      0.000009          0.016800    0.0949    0.425
# 15652     0       0.0631      0.002610          0.000001    0.1090    0.578
# 15061     1       0.0442      0.011700          0.009940    0.3470    0.404
# 23606     0       0.0692      0.098300          0.000184    0.1090    0.634
#
#          tempo  duration_ms
# 9166   170.606       248893
# 15925  110.030       220413
# 15652   85.076       292360
# 15061  135.225       373512
# 23606  149.884       164000

# %%
df_song_album.sample(5)
# Out:
#                      track_id          track_album_id
# 9657   28yT0sZlkqStSByo1j58J4  5ebuKilSgCLSvf0fO0q5bq
# 11051  46D8MyZ8htLBj7BjblMyeX  08FuW6Ze2LksgpPpjRqJTd
# 26368  7gxJ4A7XuV9ZHw6ZrTpfp7  1GgYAlgZeF91MzCUH8WGTk
# 6112   3XiNC94b4Tq1xwv70sQJGN  49K82qcZN4u109e6Zw8io1
# 5080   0TEekvXTomKt3hdXDZxxeW  6rnzvZhe3PA57xKcKLRtJ6

# %%
df_song_playlist.sample(5)
# Out:
#                      track_id             playlist_id
# 11497  4zEvxRDaKDoFlHxK7Hy0wg  4E3K9oQgvLcKEz0wgBBXxD
# 11506  18URo35acNKRTHfEdjTcGn  6BKqPGcrFMy6TczW0R5Vsz
# 26854  7sYAS4CpbV90oSemgaEQat  1G0q0NK7g3C0XerNqq7GbL
# 4512   3VsiR8bSkmnqtuLASAbwz3  1pZWCY50kMUhshcESknir8
# 18915  2PUbdd0s68EfVKlBCUW9Vq  37i9dQZF1DX8SfyqmSFDwe

# %%
df_playlist_.sample(5)
# Out:
#                   playlist_id                       playlist_name  \
# 13195  6gUFdcGzKAHyDXY9TKC6cP             Classic Rock Retrogamer
# 4346   16RNbqnNCCLlBJti7JU5nc             2019 in Indie Poptimism
# 9789   4sGnz2x5tbHE2YlW1nemfb  Rap Party 24/7 Radio / Gangsta Rap
# 28802  6mMk6QCzEgT3QGaCV1R4S5                    Dancefloor Beats
# 10860  37i9dQZF1DWWlW7KLhEhCZ                           Dose Trap
#
#       playlist_subgenre
# 13195      classic rock
# 4346    indie poptimism
# 9789       gangster rap
# 28802          big room
# 10860              trap

# %%
df_playlist_genre.sample(5)
# Out:
#       playlist_subgenre playlist_genre
# 8504       gangster rap            rap
# 19703     latin hip hop          latin
# 28301          big room            edm
# 16204          tropical          latin
# 25153          neo soul            r&b

# %%
df_album.sample(5)
# Out:
#                track_album_id                track_album_name  \
# 1745   2D0Hi3Jj6RFnpWDcSa0Otu             Youngblood (Deluxe)
# 5785   3cXkzvtDOyah8H8CYtvYcN    Emiway-Samajh Mein Aaya Kya?
# 11043  6F118EZBUwaChr38bV5Nps                          Besame
# 26809  5JoTcJ5AuSO19ZgPSfNsHl  Damn Daniel (Bombs Away Remix)
# 3593   2uxG4gg4WnqR5eriMN6ehS                   Greatest Hits
#
#       track_album_release_date
# 1745                2018-06-15
# 5785                2018-10-10
# 11043               2018-05-14
# 26809               2016-03-04
# 3593                2010-01-01

# %% [markdown]
# ## Store it in Sqlite3

# %%
# Create a database to connect to in memory
cr = sqlite3.connect('spotify.db')

# Store dataframes in the database
df_song.to_sql(name='df_song', con=cr, index = False)
df_song_album.to_sql(name='df_song_album', con=cr, index = False)
df_song_playlist.to_sql(name='df_song_playlist', con=cr, index = False)
df_playlist_.to_sql(name='df_playlist', con=cr, index = False)
df_playlist_genre.to_sql(name='df_playlist_genre', con=cr, index = False)
df_album.to_sql(name='df_album', con=cr, index = False)

# %% [markdown]
# ## Connect

# %%
# %sql sqlite:///spotify.db
# Out:
# 'Connected: @spotify.db'

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///spotify.db
# Done.
# [('table', 'df_song', 'df_song', 2, 'CREATE TABLE "df_song" (\n"track_id" TEXT,\n  "track_name" TEXT,\n  "track_artist" TEXT,\n  "track_popularity" INTEGER,\n  "danceability" REAL,\n  "e ... (79 characters truncated) ... hiness" REAL,\n  "acousticness" REAL,\n  "instrumentalness" REAL,\n  "liveness" REAL,\n  "valence" REAL,\n  "tempo" REAL,\n  "duration_ms" INTEGER\n)'),
#  ('table', 'df_song_album', 'df_song_album', 1041, 'CREATE TABLE "df_song_album" (\n"track_id" TEXT,\n  "track_album_id" TEXT\n)'),
#  ('table', 'df_song_playlist', 'df_song_playlist', 1408, 'CREATE TABLE "df_song_playlist" (\n"track_id" TEXT,\n  "playlist_id" TEXT\n)'),
#  ('table', 'df_playlist', 'df_playlist', 1826, 'CREATE TABLE "df_playlist" (\n"playlist_id" TEXT,\n  "playlist_name" TEXT,\n  "playlist_subgenre" TEXT\n)'),
#  ('table', 'df_playlist_genre', 'df_playlist_genre', 1835, 'CREATE TABLE "df_playlist_genre" (\n"playlist_subgenre" TEXT,\n  "playlist_genre" TEXT\n)'),
#  ('table', 'df_album', 'df_album', 1836, 'CREATE TABLE "df_album" (\n"track_album_id" TEXT,\n  "track_album_name" TEXT,\n  "track_album_release_date" TEXT\n)')]

# %%
# %%sql
# SELECT *
# FROM df_song
# LIMIT 5
# Out:
#  * sqlite:///spotify.db
# Done.
# [('6f807x0ima9a1j3VPbc7VN', "I Don't Care (with Justin Bieber) - Loud Luxury Remix", 'Ed Sheeran', 66, 0.748, 0.9159999999999999, 6, -2.634, 1, 0.0583, 0.102, 0.0, 0.0653, 0.518, 122.036, 194754),
#  ('0r7CVbZTWZgbTCYdfa2P31', 'Memories - Dillon Francis Remix', 'Maroon 5', 67, 0.726, 0.815, 11, -4.968999999999999, 1, 0.0373, 0.0724, 0.00421, 0.35700000000000004, 0.693, 99.97200000000001, 162600),
#  ('1z1Hg7Vb0AhHDiEmnDE79l', 'All the Time - Don Diablo Remix', 'Zara Larsson', 70, 0.675, 0.9309999999999999, 1, -3.432, 0, 0.0742, 0.0794, 2.33e-05, 0.11, 0.613, 124.008, 176616),
#  ('75FpbthrwQmzHlBJLuGdC7', 'Call You Mine - Keanu Silva Remix', 'The Chainsmokers', 60, 0.718, 0.93, 7, -3.778, 1, 0.102, 0.0287, 9.43e-06, 0.204, 0.27699999999999997, 121.956, 169093),
#  ('1e8PAfcKUYoKkxPhrHqw4x', 'Someone You Loved - Future Humans Remix', 'Lewis Capaldi', 69, 0.65, 0.833, 1, -4.672, 1, 0.0359, 0.0803, 0.0, 0.0833, 0.725, 123.976, 189052)]

# %% [markdown]
# #### Use an SQL query to find the names of all playlists that contain instrumentals.

# %%
# %%sql
# SELECT COUNT(instrumentalness) AS num_instrumentals, playlist_name
# FROM df_song
# INNER JOIN df_song_playlist
# ON df_song_playlist.track_id = df_song.track_id
# INNER JOIN df_playlist
# ON df_playlist.playlist_id = df_song_playlist.playlist_id
# WHERE instrumentalness > 0
# GROUP BY playlist_name
# ORDER BY num_instrumentals DESC
# Out:
#  * sqlite:///spotify.db
# Done.
# [(222, 'Indie Poptimism'),
#  (196, 'Fitness Workout Electro | House | Dance | Progressive House'),
#  (184, 'Permanent Wave'),
#  (172, 'Ultimate Indie Presents... Best Indie Tracks of the 2010s'),
#  (153, 'Hard Rock Workout'),
#  (138, 'Classic Rock 70s 80s 90s, Rock Classics - 70s Rock, 80s Rock, 90s Rock Rock  Classicos'),
#  (129, '2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥'),
#  (116, 'permanent wave'),
#  (114, 'EDM 2020 House & Dance'),
#  (111, 'Urban Contemporary'),
#  (100, 'Nasty Bits'),
#  (100, 'Lush Lofi'),
#  (100, 'Jazz Vibes'),
#  (99, 'Latin Hip Hop/Freestyle'),
#  (99, 'House Electro 2019'),
#  (99, 'Electropop And Play'),
#  (99, 'Electro Posé - Discoveries'),
#  (99, 'Deep Electronic Music 2020 & Progressive House'),
#  (98, '💊ELECTRO-HOUSE-TECH💊'),
#  (97, 'New Jack Swing'),
#  (96, 'Tropical Vibes'),
#  (96, 'Trap Mojito'),
#  (96, 'Music&Other Drugs'),
#  (96, 'Electro/Progressive/Club House'),
#  (96, 'Electro Swing Top 100'),
#  (96, 'Bounce United'),
#  (96, 'Big Room House | Festival Bangers'),
#  (95, 'Jeff Seid Electro House'),
#  (95, 'Indie/Jazz Poptimism'),
#  (94, '🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/2019🔥'),
#  (94, 'Selected House'),
#  (94, 'Lofi Hip-Hop'),
#  (93, 'Urban contemporary'),
#  (93, 'Techno House 2020 👽 Best Collection 👻 Top DJ’s Electronic Music - Deep House - Trance - Tech House - Dance - Electro Pop'),
#  (93, 'Lo-Fi Beats'),
#  (93, 'House/Electro/Progressive/Disco/Lofi/Synthwave'),
#  (92, 'Underground Party | Hypnotic | Minimal | Acid | Big Room | Tech | Liquid'),
#  (92, 'Latin Village 2019'),
#  (92, "80's Freestyle/Disco Dance Party (Set Crossfade to 4-Seconds)"),
#  (90, 'big boom room — TOMORROWLAND EDC EDM BIG ROOM AMF ADE DANCE TRANCE HARDWELL TIESTO'),
#  (90, 'Chillout & Remixes 💜'),
#  (90, 'Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs'),
#  (89, 'Gothic / Industrial / Mittelalter / EBM / Futurepop / Gothik / Electropop'),
#  (88, 'Maxi Pop  GOLD (New Wave, Electropop, Synth Pop...)'),
#  (87, 'Vocal House'),
#  (87, 'NEO FUNK AND SOUL'),
#  (87, 'Japanese Funk/Soul/NEO/Jazz/Acid'),
#  (86, 'Epic Bass Drops'),
#  (86, 'Big Room EDM'),
#  (86, '90s Dance Hits'),
#  (86, '70s Hard Rock'),
#  (85, 'The Sound of Permanent Wave'),
#  (85, 'Indie Poptimism!'),
#  (84, 'Hands Up\u200f\u200f\u200b\u200b   \u200d'),
#  (84, '80s Pop & Rock Hits and Album Tracks'),
#  (83, 'Rock Classics'),
#  (83, 'House Of The Rising Sun'),
#  (83, 'Gym (Melbourne Bounce/Progressive House)'),
#  (83, 'BIG-ROOM NEVER DIES !'),
#  (82, 'Tropical House'),
#  (82, 'Neo Soul / Modern Jazz / Smooth Hiphop'),
#  (82, 'Classic Hard Rock'),
#  (82, 'Badass Rock'),
#  (81, 'City Pop 1985 シティーポップ'),
#  (81, '2011-2014 House'),
#  (80, '’80s Hard Rock'),
#  (80, 'Sexy Soul 2020'),
#  (79, 'Trap Nation 🔊'),
#  (79, 'The 1950s/1960s/1970s/1980s/1990s/2000s/2010s with pop/r&b/soul/boogie/dance/jazz/hip hop/hop/rap.'),
#  (78, 'Vibra Tropical'),
#  (78, 'Epic Bass Drops | Best House Mixes'),
#  (77, 'HARD ROCK CAFE'),
#  (77, 'Groovy // Funky // Neo-Soul'),
#  (77, 'EDM 2019'),
#  (77, '70s Pop & Rock Hits and Deep Tracks'),
#  (76, 'NEO-soul'),
#  (76, 'Hard Rock'),
#  (76, 'CHRISTIAN ELECTRO / DANCE / EDM'),
#  (76, '@deniceemoberg EDM - POP REMIXES'),
#  (75, 'EDM - pop remixes'),
#  (74, 'Trap Nation'),
#  (74, 'The Edge of Indie Poptimism'),
#  (74, 'Southern Rock/Classic Rock'),
#  (74, 'Dance Pop'),
#  (74, '< DARK TRAP >'),
#  (73, 'The Sound of Album Rock'),
#  (73, 'Deep-deep Bubble Pop'),
#  (72, 'Tropical Morning'),
#  (72, 'The Queen - La Discografia Completa'),
#  (72, 'Sunny Beats'),
#  (72, 'Progressive Rock / Metal - Rock /Metal  Progresivo'),
#  (72, 'Permanent wave'),
#  (72, "L' ALBUM ROCK"),
#  (72, 'Electro Swing'),
#  (72, 'Classic Rock'),
#  (71, 'Trending EDM by Nik Cooper'),
#  (71, 'Pop Dance Hits'),
#  (71, 'Bluegrass Covers'),
#  (71, "80's Songs | Top 💯 80s Music Hits"),
#  (70, 'Rock Hard'),
#  (69, 'indie poptimism'),
#  (69, 'Hard Rock Classics 1967-1991 (Party Edition)'),
#  (68, '②⓪①⑨ mixed'),
#  (68, 'Tropical House 2020'),
#  (68, 'Neo-Soul / Soulful R&B'),
#  (68, 'ELECTROPOP EN ESPAÑOL'),
#  (68, 'Big Room 2019'),
#  (67, 'Neo-Jazz Soul RnB & Afro'),
#  (66, 'Waves Pop and EDM'),
#  (66, 'Hard Rock Cafe Classics'),
#  (66, 'Big Room Beast'),
#  (65, 'Trance Party 2019 by FUTURE TRANCE'),
#  (65, 'Neo Soul Music'),
#  (65, 'Festival Music 2019 - Warm Up Music (EDM, Big Room & Progressive House)'),
#  (64, '2019 in Indie Poptimism'),
#  (63, 'The Sound of Indie Poptimism'),
#  (63, 'Supernatural Classic Rock'),
#  (63, 'Permanent Wave CHDB'),
#  (62, 'I didn’t know perm stood for permanent (wave)'),
#  (62, 'Electrónica, Progressive House, Electro House y más 🎧'),
#  (62, 'BALLARE - رقص'),
#  (62, "90's NEW JACK SWING"),
#  (62, '80s / Classic Rock'),
#  (61, 'New Hard Rock'),
#  (61, 'Fresh EDM | Progressive House | Electro House | Trap | Deep House | Electronic | Future House/Bass'),
#  (61, 'EDM TROPICAL'),
#  (61, 'Classic Rock Drive'),
#  (61, "90's Hip Hop Ultimate Collection"),
#  (60, 'Workday: Rock Classics'),
#  (60, 'Tropical House Remixes 🍍 Tropical Remixes & Tropical Covers'),
#  (60, 'Soft Rock Drive'),
#  (60, 'Female Vocal EDM'),
#  (59, '♥ EDM LOVE 2020'),
#  (59, 'Workout Hard Rock'),
#  (59, 'Pop EDM Remixes'),
#  (59, 'Classic Rock Greatest Hits'),
#  (58, '🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENNA || BROEDERS || HENKIE T  || BIZZEY || POKE \\\\'),
#  (58, "random playlist that can't decide its genre so go ahead jam along with these catchy tunes"),
#  (58, 'a taste of the mainstream'),
#  (58, 'Saxophone in Hip Hop - R&B Lounge - Jazz Rap'),
#  (58, 'Minitruckin Playlist'),
#  (58, "HIP-HOP: Latin Rap ['89-present]"),
#  (58, 'Electro House 2020'),
#  (58, 'ELECTROPOP🐹'),
#  (58, 'Classic Rock Retrogamer'),
#  (58, 'Brand New EDM'),
#  (58, 'Alex Workout'),
#  (57, 'post teen pop'),
#  (57, 'keg party jukebox'),
#  (57, 'Paraiso Tropical'),
#  (57, "Electro House - by Spinnin' Records"),
#  (55, 'Tropical House 🏝 2020 Hits'),
#  (55, 'New Jack Swing/ R&B Hits: 1987 - 2002'),
#  (55, 'Modern Indie Rock // Alternative Rock / Garage Rock / Pop Punk / Grunge / Britpop / Pop Rock'),
#  (55, 'Great Pops'),
#  (55, 'Electropop Hits  2017-2020'),
#  (55, "Dr. Q's Prescription Playlist💊"),
#  (55, "70's Classic Rock"),
#  (54, 'urban CONTEMPORARY'),
#  (54, 'Urbano: Latino Vibes'),
#  (54, 'Global X'),
#  (53, 'Pop Hits 2000-2019'),
#  (53, 'Pop EDM'),
#  (53, 'Neo Soul'),
#  (52, 'Reggaeton Classics'),
#  (52, 'Happy EDM'),
#  (52, 'Flow Selecto'),
#  (52, 'Blues Rock'),
#  (51, 'Arabic Trap'),
#  (50, 'Southern Soul BBQ Mix'),
#  (50, 'Pop Remix'),
#  (50, 'New House   \u200d'),
#  (49, 'The Pulse of Indie Poptimism'),
#  (49, 'Rap Party 24/7 Radio / Gangsta Rap'),
#  (49, 'Mexican Gangsta Rap'),
#  (49, 'LATIN FLOW MIX - Música Cristiana🎵'),
#  (49, 'Hard Rock Workout!'),
#  (49, 'Electro House Top Tracks'),
#  (49, 'Afro Psychedelica'),
#  (48, 'Southern Hip Hop'),
#  (48, 'Soul Coffee (The Best Neo-Soul Mixtape ever)'),
#  (48, 'Neo-Soul Essentials'),
#  (47, 'This Is: Javiera Mena'),
#  (47, 'Smooth Hip Hop'),
#  (47, 'New R&B\u200f\u200f\u200b\u200b   \u200d'),
#  (47, 'New Jack City'),
#  (47, 'Hot Latino Mix (Latin, Hip Hop, Rap, RnB, Dancehall, Reggeaton, Afro)'),
#  (47, 'Electropop 2019'),
#  (47, 'Electro Pop | Electropop'),
#  (47, 'EDM/POP'),
#  (47, "Big Room EDM - by Spinnin' Records"),
#  (47, '90s R&B - The BET Planet Groove/Midnight Love Mix'),
#  (46, 'Sick Big Room House Drops | EZUMI'),
#  (46, 'PROJECT: Contemporary'),
#  (46, 'Electro House'),
#  (46, 'ELECTROPOP'),
#  (45, "This Is Guns N' Roses"),
#  (45, 'Pop Inglés (2020 - 2010s)💙 Música En Inglés 2010s'),
#  (45, 'Chicano Rap'),
#  (45, '90s Hiphop / Gangsta Rap'),
#  (44, 'The Sound of Urban Contemporary'),
#  (44, "R&B 80's/90's/00's"),
#  (44, 'Latin/Hip Hop/Dancehall/Soca'),
#  (44, 'Dance Pop Tunes'),
#  (44, '80s-90s R&B / New Jack Swing / Funk / Dance / Soul'),
#  (43, "Today's Hits (Clean)"),
#  (43, 'The Black Album'),
#  (43, 'SINULOG Festival 2020'),
#  (43, 'PAROOKAVILLE - Big Room'),
#  (43, "Kenny B's Ultimate New Jack Swing Mix"),
#  (43, 'Crossfit\u200f\u200f\u200b\u200b   \u200d'),
#  (42, '◤ Hip Hop Dance Music – Urban – Trap – Breaking Locking Popping Bopping – WOD – World of Dance'),
#  (42, 'Ultimate Indie Presents... Best Tracks of 2019'),
#  (42, 'Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop'),
#  (42, 'POPTIMISM'),
#  (42, 'Dancefloor Beats'),
#  (41, 'I Love My Neo-Soul'),
#  (41, 'Fiesta Latina Mix 🎈🎉💃🏻🕺🏻☀️🏖'),
#  (41, 'Electropop'),
#  (41, 'EDM Trap'),
#  (40, 'REGGAETON VIEJO'),
#  (40, 'HIP&HOP'),
#  (40, 'EDM House & Dance'),
#  (40, 'Club Mix 2020 🍹'),
#  (40, 'A Loose Definition of Indie Poptimism'),
#  (39, "🔥💵 Hip Hop, Rap, Heavy 808's - New School"),
#  (39, 'Trap 2020 🔥'),
#  (39, "Today's Hits 2000-Present"),
#  (39, 'Reggaeton viejito🔥'),
#  (39, 'Latin Pop Classics'),
#  (39, 'Latest Hits 2020 - Pop, Hip Hop & RnB'),
#  (39, 'Indie Poptimism (PUBLIC, The Band CAMINO, lovelytheband)'),
#  (39, "Hip-Hop 'n RnB"),
#  (39, 'HARD ROCK Vibes'),
#  (39, 'Dance Room'),
#  (39, 'Christian Dance Party'),
#  (39, "90's Southern Hip Hop"),
#  (38, 'latin hip hop'),
#  (38, 'Ultimate Throwbacks Collection'),
#  (38, 'The Cranberries Best Of'),
#  (38, 'Southern California Hip Hop Primer'),
#  (38, 'Neo-Soul'),
#  (38, 'INDIE POP! TUNES'),
#  (38, 'Classic Rock Now'),
#  (37, 'Unplugged Hits 📣'),
#  (37, 'Pop / Dance'),
#  (37, 'GTA V - Radio Mirror Park'),
#  (37, 'Christmas Soul'),
#  (37, '2015 songs'),
#  (37, "2000's hard rock"),
#  (36, 'post-teen alternative, indie, pop (large variety)'),
#  (36, 'Reggaeton De Ayer'),
#  (36, 'Pop Punk | Post-Hardcore'),
#  (36, 'Orgulho Tropical'),
#  (36, 'Muse Radio - (Uprising, Starlight, Supermassive Black Hole, Madness)'),
#  (36, 'Classic Rock Legends'),
#  (35, 'Tropical Beats'),
#  (35, 'Reggaeton 2020 ☀'),
#  (35, 'Gospel Neo Soul'),
#  (35, 'Big Room House / Bigroom'),
#  (34, 'The Sound of New Jack Swing'),
#  (34, 'School Dance 2019 (Squeaky Clean)'),
#  (34, 'Pinoy Classic Rock'),
#  (33, 'New Jack Swing | The Best 👌'),
#  (33, 'Neo Soul 2019'),
#  (33, 'Mix ElectroPop//ElectroHouse// DeepHouse 2020'),
#  (33, 'LATIN POP 2020 🔥 Pop latino actual'),
#  (33, 'Exitos 2020 - Latin Billboard'),
#  (33, 'Contemporary Urban'),
#  (33, '2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 - 2017 - 2018 - 2019 - 2020 TOP HITS'),
#  (32, 'Tropical House 🌴'),
#  (32, 'Trapperz'),
#  (32, 'ElectroPop'),
#  (31, 'This Is Logic'),
#  (31, 'The Sound of Post-Teen Pop'),
#  (31, 'New Jack Swing - 90s R&B fused w Hip Hop'),
#  (31, 'Modus Mio'),
#  (31, 'Hip Hop Controller'),
#  (31, 'ElectroPop 2020'),
#  (31, 'Dance Pop Hits'),
#  (31, 'Cuban vibes only'),
#  (31, 'Classic Rock Radio'),
#  (31, 'Back in the day - R&B, New Jack Swing, Swingbeat, RNB..etc.'),
#  (31, '90s/00s Hip Hop & RnB'),
#  (30, 'VidaLoca - Latin / Raggaeton / Hip Hop ©'),
#  (30, 'Trap strefa'),
#  (30, 'This Is Janelle Monáe'),
#  (30, 'Tastemakers Ball  -  EDM - POP and FUN'),
#  (30, 'Swingbeat (old skool), New Jack Swing, R&B, Hip Hop, Urban'),
#  (30, 'Post Teen Pop'),
#  (30, 'Paraíso Tropical'),
#  (30, 'Los Cangri'),
#  (30, 'Girl On Fire'),
#  (30, 'Classic Rock Playlist.'),
#  (30, 'Baila Reggaeton'),
#  (29, '[EAS]: Festival Big Room'),
#  (29, 'Sad Trap'),
#  (29, 'Russian Gangster Rap'),
#  (29, 'Oldschool Gangsta Rap 👑'),
#  (29, "Gangsta Rap/90's Hip-Hop"),
#  (29, 'GANGSTA Rap'),
#  (29, 'De Fiesta'),
#  (29, 'Chixtape 5 - Tory Lanez'),
#  (29, '10er Playlist'),
#  (28, "Rock Ballads 80s 90s | Best Rock Love Songs 80's 90's Music Hits"),
#  (28, 'Hip pop'),
#  (28, 'ELECTRO HOUSE 2020'),
#  (28, 'Dance Pop: Japan'),
#  (28, '90s Gangsta Rap / Top Hip-hop Classics'),
#  (28, '1987-1997 OLD SKOOL JAMZ'),
#  (27, 'urban contemporary'),
#  (27, 'indie poptimism🕺🏻'),
#  (27, 'Verão 2020 | Pop | Funk | Sertanejo | EDM | Top Hits 2019 - As Mais Tocadas'),
#  (27, 'Post pop teen'),
#  (27, 'Neo-Soul Guitar'),
#  (27, 'NEO SOUL GUITAR'),
#  (27, 'Electropop - Pop'),
#  (27, 'Alternative Hip Hop'),
#  (26, 'This Is Scorpions'),
#  (26, 'Reggaeton Rewind'),
#  (26, 'Latin Pop antiguo'),
#  (26, 'Gospel'),
#  (26, '90s-2000s Southern Hip Hop / Crunk'),
#  (25, 'Pop Warmup 130 BPM'),
#  (25, 'Gangsta Rap 💎 Rap Party'),
#  (24, 'Tropical Rising'),
#  (24, 'Todo Reggaeton'),
#  (24, 'This Is: Don Omar'),
#  (24, 'TUNES DANCE AND POP'),
#  (24, 'Pop Hits 2020'),
#  (24, 'GTA San Andreas Radio Los Santos'),
#  (23, '🤩🤪Post Teen Pop🤪🤩'),
#  (23, 'New Hip Hop\u200f\u200f\u200b\u200b   \u200d'),
#  (23, 'Latest Latin American Hits 2020'),
#  (23, 'Hip-Hop Drive'),
#  (23, 'Big Room House'),
#  (23, 'Academia Reggaetón'),
#  (22, 'Urban/Trap - Contemporary RAP'),
#  (22, 'Todo Éxitos'),
#  (22, 'Gangster Rap Deutsch'),
#  (22, 'Feeling Accomplished'),
#  (22, 'Best of 2019 Dance Pop: Japan'),
#  (22, 'Arena Hip-Hop'),
#  (21, 'Trap Luv'),
#  (21, 'Trap Argentino - Trap Argentina'),
#  (21, 'Soda Stereo – El Ultimo Concierto'),
#  (21, 'RUSSIAN Gangster Rap'),
#  (21, 'RAP 91'),
#  (21, 'Permanent wave 🌊'),
#  (21, 'Latin Pop 2019'),
#  (21, '"Permanent Wave"'),
#  (20, 'Trap Americana'),
#  (20, 'RAP Gangsta'),
#  (20, 'Perreo City'),
#  (20, "Nikki Sixx's Top Pixx"),
#  (20, 'K-Crazy Michioso Tunes'),
#  (20, 'Gangster Rap'),
#  (20, 'Electro Vibes'),
#  (19, 'Trapperz Argentina'),
#  (19, 'Trap Land'),
#  (19, 'Top Urban Underground'),
#  (19, 'Southern soul & hip hop'),
#  (19, 'Reggaeton 2020 😍 🔥'),
#  (19, 'Punto Tropical'),
#  (19, 'Most Popular 2020 TOP 50'),
#  (19, 'Latin Pop Rising'),
#  (19, 'Caifanes La Historia'),
#  (18, 'Tusa - Karol G | China - Anuel AA | Estrenos Reggaeton y Música Urbana 2019'),
#  (18, 'The Sound of Southern Hip Hop'),
#  (18, 'Rock and Rios'),
#  (18, 'Musica Italiana 2020 - Playlist Pop & Hip-Hop (Canzoni Italiane 2020)'),
#  (18, 'MIX LATIN POP°'),
#  (18, 'Latin Pop VIP'),
#  (18, 'K-Party Dance Mix'),
#  (18, 'Gangster Rap Workout'),
#  (18, 'Electropop 80/90s'),
#  (18, 'El Ritmo'),
#  (18, 'Cardio'),
#  (18, 'A1 Hip-Hop'),
#  (17, 'Tropical Nights'),
#  (17, 'Trap Ouro'),
#  (17, 'Rap Workout'),
#  (17, 'Latin Pop Songs'),
#  (17, 'Contemporary Hip Hop'),
#  (16, 'Trap Funk'),
#  (16, 'This Is Gloria Estefan'),
#  (16, 'SNZB PERMANENT WAVE'),
#  (16, 'Dose Trap'),
#  (16, 'Dirty South Rap Classics by DJ HOTSAUCE'),
#  (15, 'Trapperz Brasil'),
#  (14, 'TROPICAL🌴'),
#  (14, 'Rock Hubspot'),
#  (14, 'Global Top 50 | 2020 Hits'),
#  (14, 'DK rap'),
#  (14, "90's Gangster Rap"),
#  (14, '3rd Coast Classics'),
#  (13, 'Viral Southern Hip Hop'),
#  (13, 'Vault: Def Leppard Greatest Hits'),
#  (13, 'Permanent Wave Cafe'),
#  (13, 'Mansión Reggaetón'),
#  (13, 'Latin Hip Hop & Rap Playlist 2019'),
#  (13, 'Hip-Hop Mixtape'),
#  (13, 'Generacja Hip Hop'),
#  (13, 'Classic Rock Workout'),
#  (12, 'Zona Trap'),
#  (12, 'The New (Jack Swing) Testament'),
#  (12, 'REGGAETON ANTIGUO 🔥'),
#  (12, 'Pop 2009-2011'),
#  (12, 'Coldplay – Ghost Stories (Deluxe Edition)'),
#  (11, 'Tropical House Run 190 BPM'),
#  (11, "New Jack Swing -late 80's & early 90's Hip Hop and R&B"),
#  (11, 'Hip-Hop Central'),
#  (11, 'Gangster Rap | 100 % Gangster'),
#  (11, 'F**KIN PERFECT'),
#  (11, 'Brisa Pop'),
#  (10, 'Mega Rock Ballads: The Best Slow Rock Compilation Ever !'),
#  (10, 'Intro to Indie Poptimism'),
#  (10, 'Fresh Essentials'),
#  (9, 'post-teen pop'),
#  (9, 'Trap Rewind'),
#  (9, 'Locker Room'),
#  (8, 'Verano Forever'),
#  (8, 'URBAN NATION'),
#  (8, 'Hip-Hop Favourites'),
#  (8, 'Hip Te Hop'),
#  (8, 'GANGSTA RAP'),
#  (7, 'RapCaviar'),
#  (7, 'Post teen pop'),
#  (7, 'Hip Pop 2019'),
#  (7, 'Best of New Jack Swing'),
#  (6, 'RADIO POP CHARTS'),
#  (6, 'Intro to Permanent Wave'),
#  (6, 'ELETRIC POP & DANCE'),
#  (5, 'Pop Latino 2019 - Mix Canciones Reggaeton & Pop Latino - Pop En Español 2019 Musica Para Bailar'),
#  (5, 'Michael Learns To Rock album'),
#  (5, 'EDM Pop'),
#  (5, 'CSR 103:9 (GTA: SA)'),
#  (4, '¡Viva Latino!'),
#  (4, 'Someone You Loved Lewis Capaldi (Pop Music Mix)'),
#  (4, 'Post-teen pop'),
#  (4, 'Nidza Bleja - English HIP HOP/POP Songs'),
#  (3, 'ONE OK ROCK with Orchestra Japan Tour 2018 Setlist'),
#  (3, 'LATIN POP- DJ GIAN'),
#  (3, 'Intro to Post-Teen Pop'),
#  (3, 'ALPAS Music Festival'),
#  (2, 'TOP 50 GLOBAL 2020 UPDATED WEEKLY 🌍🎶 WORLDWIDE'),
#  (2, 'Pop / Hip-Hop: Gas ⛽️'),
#  (2, 'Big White Room-Jessie-J'),
#  (1, 'Post-Teen Pop')]

# %%
# %%sql
# SELECT COUNT(*)
# FROM
# (SELECT SUM(instrumentalness) AS num_instrumentals, playlist_name
# FROM df_song
# INNER JOIN df_song_playlist
# ON df_song_playlist.track_id = df_song.track_id
# INNER JOIN df_playlist
# ON df_playlist.playlist_id = df_song_playlist.playlist_id
# GROUP BY playlist_name
# HAVING num_instrumentals > 0
# ORDER BY num_instrumentals DESC)
# Out:
#  * sqlite:///spotify.db
# Done.
# [(449,)]

# %% [markdown]
# There are 449 playlists that had at least one song that contains instrumentals.

# %% [markdown]
# ##### check with the original dataframe

# %%
np.sum(df[df.playlist_name == 'Indie Poptimism'].instrumentalness > 0 )
# Out:
# 222

# %% [markdown]
# This is the same as the result in SQL query.
